# %% [markdown]
# # Rule Generator (Decision Tree algorithm) Example

# %% [markdown]
# This notebook contains an example of how the Rule Generator (Decision Tree algorithm) can be used to create rules based on a labelled dataset. This algorithm generate rules by extracting the highest performing branches from a tree ensemble model.

# %% [markdown]
# ## Requirements

# %% [markdown]
# To run, you'll need the following:
#
# * Install the Rule Generator (Decision Tree algorithm) package - see the readme for more information.
# * A labelled, processed dataset (i.e. nulls imputed, categorical features one hot encoded, feature selection applied)

# %% [markdown]
# ----

# %% [markdown]
# ## Import packages

# %%
from rule_generation.rule_generator_dt import RuleGeneratorDT

import random
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Read in data

# %% [markdown]
# Let's read in some labelled, processed dummy data.

# %%
X_train = pd.read_csv('dummy_data/X_train.csv', index_col='eid')
y_train = pd.read_csv('dummy_data/y_train.csv', index_col='eid').squeeze()
X_test = pd.read_csv('dummy_data/X_test.csv', index_col='eid')
y_test = pd.read_csv('dummy_data/y_test.csv', index_col='eid').squeeze()

# %% [markdown]
# ----

# %% [markdown]
# ## Generate rules

# %% [markdown]
# ### Set up class parameters

# %% [markdown]
# Now we can set our class parameters for the Rule Generator. Here we're using the F1 score as the optimisation function (you can choose a different function from the optimisation_functions module or create your own).
#
# **Note that if you're using the FScore, Precision or Recall score as the optimisation function, use the *FScore*, *Precision* or *Recall* classes in the *optimisation_functions* module rather than the same functions from Sklearn's *metrics* module, as the former are ~100 times faster on larger datasets.**
#
# **Please see the class docstring for more information on each parameter.**

# %%
from rule_optimisation.optimisation_functions import FScore
fs = FScore(beta=1)

# %%
params = {
    'n_total_conditions': 4,
    'opt_func': fs.fit,
    'tree_ensemble': RandomForestClassifier(n_estimators=100, random_state=0),
    'precision_threshold': 0.5,
    'num_cores': 4
}

# %% [markdown]
# ### Instantiate class and run fit method

# %% [markdown]
# Once the parameters have been set, we can run the *.fit()* method to generate rules.

# %%
rg = RuleGeneratorDT(**params)
X_rules = rg.fit(X=X_train, y=y_train, sample_weight=None)

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.fit()* method returns a dataframe giving the binary columns of the generated rules as applied to the training dataset.
#
# Useful attributes created by running the *.fit()* method are:
#
# * rule_descriptions: A dataframe showing the logic of the generated rules and their performance metrics as applied to the training dataset.
# * rules: Class containing the rule stored in the standard ARGO string format. Methods from this class can be used to convert the rules into the standard ARGO dictionary or lambda expression representations. See the *rules* module for more information.

# %%
X_rules.head()
# Out:
# Rule                 RGDT_Rule_20210226_298  RGDT_Rule_20210226_67  \
# eid
# 867-8837095-9305559                       0                      0
# 974-5306287-3527394                       0                      0
# 584-0112844-9158928                       0                      0
# 956-4190732-7014837                       0                      0
# 349-7005645-8862067                       0                      0
#
# Rule                 RGDT_Rule_20210226_254  RGDT_Rule_20210226_57  \
# eid
# 867-8837095-9305559                       0                      0
# 974-5306287-3527394                       0                      0
# 584-0112844-9158928                       0                      0
# 956-4190732-7014837                       0                      0
# 349-7005645-8862067                       0                      0
#
# Rule                 RGDT_Rule_20210226_115  RGDT_Rule_20210226_164  \
# eid
# 867-8837095-9305559                       0                       0
# 974-5306287-3527394                       0                       0
# 584-0112844-9158928                       0                       0
# 956-4190732-7014837                       0                       0
# 349-7005645-8862067                       0                       0
#
# Rule                 RGDT_Rule_20210226_70  RGDT_Rule_20210226_111  \
# eid
# 867-8837095-9305559                      0                       0
# 974-5306287-3527394                      0                       0
# 584-0112844-9158928                      0                       0
# 956-4190732-7014837                      0                       0
# 349-7005645-8862067                      0                       0
#
# Rule                 RGDT_Rule_20210226_123  RGDT_Rule_20210226_187  ...  \
# eid                                                                  ...
# 867-8837095-9305559                       0                       0  ...
# 974-5306287-3527394                       0                       0  ...
# 584-0112844-9158928                       0                       0  ...
# 956-4190732-7014837                       0                       0  ...
# 349-7005645-8862067                       0                       0  ...
#
# Rule                 RGDT_Rule_20210226_270  RGDT_Rule_20210226_135  \
# eid
# 867-8837095-9305559                       0                       0
# 974-5306287-3527394                       0                       0
# 584-0112844-9158928                       0                       0
# 956-4190732-7014837                       0                       0
# 349-7005645-8862067                       0                       0
#
# Rule                 RGDT_Rule_20210226_36  RGDT_Rule_20210226_32  \
# eid
# 867-8837095-9305559                      0                      0
# 974-5306287-3527394                      0                      0
# 584-0112844-9158928                      0                      0
# 956-4190732-7014837                      0                      0
# 349-7005645-8862067                      0                      0
#
# Rule                 RGDT_Rule_20210226_77  RGDT_Rule_20210226_22  \
# eid
# 867-8837095-9305559                      0                      0
# 974-5306287-3527394                      0                      0
# 584-0112844-9158928                      0                      0
# 956-4190732-7014837                      0                      0
# 349-7005645-8862067                      0                      0
#
# Rule                 RGDT_Rule_20210226_278  RGDT_Rule_20210226_7  \
# eid
# 867-8837095-9305559                       0                     0
# 974-5306287-3527394                       0                     0
# 584-0112844-9158928                       0                     0
# 956-4190732-7014837                       0                     0
# 349-7005645-8862067                       0                     0
#
# Rule                 RGDT_Rule_20210226_64  RGDT_Rule_20210226_221
# eid
# 867-8837095-9305559                      0                       0
# 974-5306287-3527394                      0                       0
# 584-0112844-9158928                      0                       0
# 956-4190732-7014837                      0                       0
# 349-7005645-8862067                      0                       0
#
# [5 rows x 299 columns]

# %%
rg.rule_descriptions.head()
# Out:
#                         Precision    Recall  PercDataFlagged  OptMetric  \
# Rule
# RGDT_Rule_20210226_298   0.991837  1.000000         0.027547   0.995902
# RGDT_Rule_20210226_67    0.991837  1.000000         0.027547   0.995902
# RGDT_Rule_20210226_254   0.995851  0.987654         0.027097   0.991736
# RGDT_Rule_20210226_57    0.995851  0.987654         0.027097   0.991736
# RGDT_Rule_20210226_115   0.995833  0.983539         0.026984   0.989648
#
#                                                                     Logic  \
# Rule
# RGDT_Rule_20210226_298  (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_67   (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_254  (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_57   (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_115  (X['account_number_num_fraud_transactions_per_...
#
#                         nConditions
# Rule
# RGDT_Rule_20210226_298            2
# RGDT_Rule_20210226_67             1
# RGDT_Rule_20210226_254            2
# RGDT_Rule_20210226_57             2
# RGDT_Rule_20210226_115            2

# %% [markdown]
# ----

# %% [markdown]
# ## Apply rules to a separate dataset

# %% [markdown]
# Use the *.apply()* method to apply the generated rules to a separate dataset.

# %%
X_rules_applied = rg.apply(X=X_test, y=y_test, sample_weight=None)

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.apply()* method returns a dataframe giving the binary columns of the rules as applied to the given dataset.
#
# A useful attribute created by running the *.apply()* method is:
#
# * rule_descriptions_applied: A dataframe showing the logic of the generated rules and their performance metrics as applied to the given dataset.

# %%
rg.rule_descriptions_applied.head()
# Out:
#                         Precision    Recall  PercDataFlagged  OptMetric  \
# Rule
# RGDT_Rule_20210226_298   0.991453  1.000000         0.026700   0.995708
# RGDT_Rule_20210226_67    0.991453  1.000000         0.026700   0.995708
# RGDT_Rule_20210226_254   0.991304  0.982759         0.026244   0.987013
# RGDT_Rule_20210226_57    0.991304  0.982759         0.026244   0.987013
# RGDT_Rule_20210226_115   0.991304  0.982759         0.026244   0.987013
#
#                                                                     Logic  \
# Rule
# RGDT_Rule_20210226_298  (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_67   (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_254  (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_57   (X['account_number_num_fraud_transactions_per_...
# RGDT_Rule_20210226_115  (X['account_number_num_fraud_transactions_per_...
#
#                         nConditions
# Rule
# RGDT_Rule_20210226_298            2
# RGDT_Rule_20210226_67             1
# RGDT_Rule_20210226_254            2
# RGDT_Rule_20210226_57             2
# RGDT_Rule_20210226_115            2

# %%
X_rules_applied.head()
# Out:
# Rule                 RGDT_Rule_20210226_298  RGDT_Rule_20210226_67  \
# eid
# 975-8351797-7122581                       0                      0
# 785-6259585-7858053                       0                      0
# 057-4039373-1790681                       0                      0
# 095-5263240-3834186                       0                      0
# 980-3802574-0009480                       0                      0
#
# Rule                 RGDT_Rule_20210226_254  RGDT_Rule_20210226_57  \
# eid
# 975-8351797-7122581                       0                      0
# 785-6259585-7858053                       0                      0
# 057-4039373-1790681                       0                      0
# 095-5263240-3834186                       0                      0
# 980-3802574-0009480                       0                      0
#
# Rule                 RGDT_Rule_20210226_115  RGDT_Rule_20210226_164  \
# eid
# 975-8351797-7122581                       0                       0
# 785-6259585-7858053                       0                       0
# 057-4039373-1790681                       0                       0
# 095-5263240-3834186                       0                       0
# 980-3802574-0009480                       0                       0
#
# Rule                 RGDT_Rule_20210226_187  RGDT_Rule_20210226_116  \
# eid
# 975-8351797-7122581                       0                       0
# 785-6259585-7858053                       0                       0
# 057-4039373-1790681                       0                       0
# 095-5263240-3834186                       0                       0
# 980-3802574-0009480                       0                       0
#
# Rule                 RGDT_Rule_20210226_70  RGDT_Rule_20210226_111  ...  \
# eid                                                                 ...
# 975-8351797-7122581                      0                       0  ...
# 785-6259585-7858053                      0                       0  ...
# 057-4039373-1790681                      0                       0  ...
# 095-5263240-3834186                      0                       0  ...
# 980-3802574-0009480                      0                       0  ...
#
# Rule                 RGDT_Rule_20210226_4  RGDT_Rule_20210226_292  \
# eid
# 975-8351797-7122581                     0                       0
# 785-6259585-7858053                     0                       0
# 057-4039373-1790681                     0                       0
# 095-5263240-3834186                     0                       0
# 980-3802574-0009480                     0                       0
#
# Rule                 RGDT_Rule_20210226_135  RGDT_Rule_20210226_194  \
# eid
# 975-8351797-7122581                       0                       0
# 785-6259585-7858053                       0                       0
# 057-4039373-1790681                       0                       0
# 095-5263240-3834186                       0                       0
# 980-3802574-0009480                       0                       0
#
# Rule                 RGDT_Rule_20210226_32  RGDT_Rule_20210226_72  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20210226_22  RGDT_Rule_20210226_18  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20210226_64  RGDT_Rule_20210226_221
# eid
# 975-8351797-7122581                      0                       0
# 785-6259585-7858053                      0                       0
# 057-4039373-1790681                      0                       0
# 095-5263240-3834186                      0                       0
# 980-3802574-0009480                      0                       0
#
# [5 rows x 299 columns]

# %% [markdown]
# ----

# %% [markdown]
# ## The End

# %% [markdown]
# That's it folks - if you have any queries or suggestions please put them in the *#sim-datatools-help* Slack channel or email James directly.
