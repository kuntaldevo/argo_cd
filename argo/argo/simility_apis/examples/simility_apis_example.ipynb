# %% [markdown]
# # Simility APIs Example

# %% [markdown]
# This notebook contains an example of how the Simility APIs sub-package can be used to make calls to a Simility environment which are relevant to the rule generation/optimisation process. Note that the modules within this sub-package all return the raw API response - use the *simility_requests* sub-package to generate objects which can be easily used in the rule generation/optimisation process.

# %% [markdown]
# ## Requirements

# %% [markdown]
# To run, you'll need the following:
#
# * Install the Simility APIs package - see the readme for more information.

# %% [markdown]
# ----

# %% [markdown]
# ## Import packages

# %%
from simility_apis.create_rule_in_simility import CreateRuleInSimilityAPI
from simility_apis.return_cassandra_entity_info import ReturnCassandraEntityInfoAPI
from simility_apis.return_rule_info_from_simility import ReturnRuleInfoFromSimilityAPI
from simility_apis.update_rule_in_simility import UpdateRuleInSimilityAPI
from simility_apis.set_password import set_password

import pandas as pd
import numpy as np
import json

# %% [markdown]
# ---

# %% [markdown]
# ## Set your password

# %% [markdown]
# Before using any of the simility_apis modules, you need to provide your password that you use to log in to the Simility environment:

# %%
set_password()
# Out:
# Please provide your password for logging into the Simility platform:  ·········

# %% [markdown]
# ---

# %% [markdown]
# ## CreateRuleInSimilityAPI

# %% [markdown]
# This class creates a rule in a Simility environment, given a stringified system-ready JSON config for the rule. See the *system_config_generation* package for more information on generating these configs.
#
# Let's say we have the following rule config and want to use the API to generate the rule in Simility:

# %%
rule_config = {
    'createdBy': 'argo@simility.com',
    'createdOn': '2021-01-12T14:26:28',
    'appPrefix': 'james_testing',
    'entityName': 'transaction',
    'name': 'Rule1',
    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.avg_order_total_per_account_number_1day", "operator": "greater", "value": "value.1.0", "id": "account_number.avg_order_total_per_account_number_1day", "type": "double"}]}',
    'score': -10,
    'status': 'ACTIVE',
    'isAutoGenerated': True
}

# %% [markdown]
# Firstly, we need to instantiate the CreateRuleInSimilityAPI class. To do this, we need to provide the *url*, *app_prefix* and *user* for the environment where the rule is to be created:

# %%
params = {
    "url": 'http://sim-ds.us-central1.gcp.dev.paypalinc.com',
    "app_prefix": 'james_testing',
    "user": 'james@simility.com'
}

# %%
c = CreateRuleInSimilityAPI(**params)

# %% [markdown]
# Then we can run the *.request()* method (and provide the rule_config) to generate the rule in the Simility environment specified. **Note that the rule config must be converted to a stringified JSON before passing it to the method.**

# %%
c.request(rule_config=json.dumps(rule_config))

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.request()* method does not return a value; however, once it has ran successfully, you should see the rule has been created in the Simility environment specified.

# %% [markdown]
# ---

# %% [markdown]
# ## UpdateRuleInSimilityAPI

# %% [markdown]
# This class updates an existing rule in a Simility environment, given a stringified system-ready JSON config for the rule. See the *system_config_generation* package for more information on generating these configs.
#
# Let's use the same rule from the previous example, but update the threshold values and the score of the rule:

# %%
rule_config = {
    'createdBy': 'argo@simility.com',
    'createdOn': '2021-01-12T14:26:28',
    'appPrefix': 'james_testing',
    'entityName': 'transaction',
    'name': 'Rule1',
    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.avg_order_total_per_account_number_1day", "operator": "greater", "value": "value.2.0", "id": "account_number.avg_order_total_per_account_number_1day", "type": "double"}]}',
    'score': -5,
    'status': 'ACTIVE',
    'isAutoGenerated': True,
    'id': 1995
}

# %% [markdown]
# Firstly, we need to instantiate the UpdateRuleInSimilityAPI class. To do this, we need to provide the *url*, *app_prefix* and *user* for the environment where the rule is to be updated:

# %%
params = {
    "url": 'http://sim-ds.us-central1.gcp.dev.paypalinc.com',
    "app_prefix": 'james_testing',
    "user": 'james@simility.com'
}

# %%
u = UpdateRuleInSimilityAPI(**params)

# %% [markdown]
# Then we can run the *.request()* method (and provide the rule_config) to update the rule in the Simility environment specified. **Note that the rule config must be converted to a stringified JSON before passing it to the method.**

# %%
u.request(rule_config=json.dumps(rule_config))

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.request()* method does not return a value; however, once it has ran successfully, you should see the rule has been updated in the Simility environment specified.

# %% [markdown]
# ---

# %% [markdown]
# ## ReturnRuleInfoFromSimilityAPI

# %% [markdown]
# This class returns the rule configuration JSONs related to the rules found in a Simility environment.

# %% [markdown]
# Firstly, we need to instantiate the ReturnRuleInfoFromSimilityAPI class. To do this, we need to provide the *url*, *app_prefix*, *entity* and *user* for the environment where the rules are located.

# %%
params = {
    "url": 'http://sim-ds.us-central1.gcp.dev.paypalinc.com',
    "app_prefix": 'james_testing',
    "entity": 'transaction',
    "user": 'james@simility.com'
}

# %%
r = ReturnRuleInfoFromSimilityAPI(**params)

# %% [markdown]
# Then we can run the *.request()* method to return the rule configuration JSONs related to each rule in the Simility environment. **Note that the response is a raw stringified JSON - we need to convert it to a dictionary before it can be used in Python.**

# %%
response = r.request()

# %%
response_dict = json.loads(response.text)

# %%
response_dict
# Out:
# {'entries': [{'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:02.681-08:00',
#    'id': 2001,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:02.681-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule137',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"condition": "OR", "rules": [{"field": "account_number.avg_order_total_per_account_number_7day", "operator": "less_or_equal", "value": "value.317.69", "id": "account_number.avg_order_total_per_account_number_7day", "type": "double"}, {"field": "account_number.avg_order_total_per_account_number_7day", "operator": "is_null", "value": null, "id": "account_number.avg_order_total_per_account_number_7day", "type": "double"}]}, {"field": "account_number.num_fraud_transactions_per_account_number_1day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_1day", "type": "integer"}, {"field": "account_number.num_fraud_transactions_per_account_number_90day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_90day", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_1day", "operator": "less_or_equal", "value": "value.782.375", "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_1day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}]}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"condition":"OR","rules":[{"id":"account_number.avg_order_total_per_account_number_7day","field":"account_number.avg_order_total_per_account_number_7day","type":"double","operator":"less_or_equal","value":"value.317.69"},{"id":"account_number.avg_order_total_per_account_number_7day","field":"account_number.avg_order_total_per_account_number_7day","type":"double","operator":"is_null"}]},{"id":"account_number.num_fraud_transactions_per_account_number_1day","field":"account_number.num_fraud_transactions_per_account_number_1day","type":"integer","operator":"greater_or_equal","value":"value.1"},{"id":"account_number.num_fraud_transactions_per_account_number_90day","field":"account_number.num_fraud_transactions_per_account_number_90day","type":"integer","operator":"greater_or_equal","value":"value.1"},{"condition":"OR","rules":[{"id":"account_number.sum_order_total_per_account_number_1day","field":"account_number.sum_order_total_per_account_number_1day","type":"double","operator":"less_or_equal","value":"value.782.375"},{"id":"account_number.sum_order_total_per_account_number_1day","field":"account_number.sum_order_total_per_account_number_1day","type":"double","operator":"is_null"}]}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'condition': 'OR',
#       'rules': [{'field': 'account_number.avg_order_total_per_account_number_7day',
#         'id': 'account_number.avg_order_total_per_account_number_7day',
#         'operator': 'less_or_equal',
#         'type': 'double',
#         'value': 'value.317.69'},
#        {'field': 'account_number.avg_order_total_per_account_number_7day',
#         'id': 'account_number.avg_order_total_per_account_number_7day',
#         'operator': 'is_null',
#         'type': 'double'}]},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'id': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_90day',
#       'id': 'account_number.num_fraud_transactions_per_account_number_90day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.sum_order_total_per_account_number_1day',
#         'id': 'account_number.sum_order_total_per_account_number_1day',
#         'operator': 'less_or_equal',
#         'type': 'double',
#         'value': 'value.782.375'},
#        {'field': 'account_number.sum_order_total_per_account_number_1day',
#         'id': 'account_number.sum_order_total_per_account_number_1day',
#         'operator': 'is_null',
#         'type': 'double'}]}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.avg_order_total_per_account_number_7day"},{"type":"DOUBLE","operator":"CONSTANT","value":"317.69"}]},{"operator":"IS_NULL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.avg_order_total_per_account_number_7day"}]}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_1day"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_90day"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_1day"},{"type":"DOUBLE","operator":"CONSTANT","value":"782.375"}]},{"operator":"IS_NULL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_1day"}]}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.avg_order_total_per_account_number_7day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 317.69}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.avg_order_total_per_account_number_7day'}]}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_1day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_90day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_1day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 782.375}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_1day'}]}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:03.269-08:00',
#    'matches': 0,
#    'rid': 2001,
#    'score': -68,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2020-10-06T10:22:55.309-07:00',
#    'id': 1802,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2020-12-21T07:42:37.391-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'CreateRuleTest2',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "order_total", "operator": "greater_or_equal", "value": "value.250.0", "id": "order_total", "type": "double"}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"order_total","field":"order_total","type":"double","operator":"greater_or_equal","value":"value.250.0"}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'order_total',
#       'id': 'order_total',
#       'operator': 'greater_or_equal',
#       'type': 'double',
#       'value': 'value.250.0'}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"order_total"},{"type":"DOUBLE","operator":"CONSTANT","value":"250.0"}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'DOUBLE',
#         'value': 'order_total'},
#        {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 250}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'javaElExpression': '',
#    'lastDateRuleConditionChanged': '2020-12-21T07:42:37.393-08:00',
#    'matches': 0,
#    'query': '',
#    'rid': 1802,
#    'ruleGroupNames': 'Test',
#    'score': -50,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:19.756-08:00',
#    'id': 2015,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:19.756-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule81',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.avg_order_total_per_account_number_1day", "operator": "greater", "value": "value.617.69", "id": "account_number.avg_order_total_per_account_number_1day", "type": "double"}, {"field": "account_number.num_fraud_transactions_per_account_number_lifetime", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_lifetime", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.num_order_items_per_account_number_30day", "operator": "less_or_equal", "value": "value.3", "id": "account_number.num_order_items_per_account_number_30day", "type": "integer"}, {"field": "account_number.num_order_items_per_account_number_30day", "operator": "is_null", "value": null, "id": "account_number.num_order_items_per_account_number_30day", "type": "integer"}]}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_1day", "operator": "less_or_equal", "value": "value.627.51999", "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_1day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}]}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.avg_order_total_per_account_number_1day","field":"account_number.avg_order_total_per_account_number_1day","type":"double","operator":"greater","value":"value.617.69"},{"id":"account_number.num_fraud_transactions_per_account_number_lifetime","field":"account_number.num_fraud_transactions_per_account_number_lifetime","type":"integer","operator":"greater_or_equal","value":"value.1"},{"condition":"OR","rules":[{"id":"account_number.num_order_items_per_account_number_30day","field":"account_number.num_order_items_per_account_number_30day","type":"integer","operator":"less_or_equal","value":"value.3"},{"id":"account_number.num_order_items_per_account_number_30day","field":"account_number.num_order_items_per_account_number_30day","type":"integer","operator":"is_null"}]},{"condition":"OR","rules":[{"id":"account_number.sum_order_total_per_account_number_1day","field":"account_number.sum_order_total_per_account_number_1day","type":"double","operator":"less_or_equal","value":"value.627.51999"},{"id":"account_number.sum_order_total_per_account_number_1day","field":"account_number.sum_order_total_per_account_number_1day","type":"double","operator":"is_null"}]}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.avg_order_total_per_account_number_1day',
#       'id': 'account_number.avg_order_total_per_account_number_1day',
#       'operator': 'greater',
#       'type': 'double',
#       'value': 'value.617.69'},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'id': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.num_order_items_per_account_number_30day',
#         'id': 'account_number.num_order_items_per_account_number_30day',
#         'operator': 'less_or_equal',
#         'type': 'integer',
#         'value': 'value.3'},
#        {'field': 'account_number.num_order_items_per_account_number_30day',
#         'id': 'account_number.num_order_items_per_account_number_30day',
#         'operator': 'is_null',
#         'type': 'integer'}]},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.sum_order_total_per_account_number_1day',
#         'id': 'account_number.sum_order_total_per_account_number_1day',
#         'operator': 'less_or_equal',
#         'type': 'double',
#         'value': 'value.627.51999'},
#        {'field': 'account_number.sum_order_total_per_account_number_1day',
#         'id': 'account_number.sum_order_total_per_account_number_1day',
#         'operator': 'is_null',
#         'type': 'double'}]}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.avg_order_total_per_account_number_1day"},{"type":"DOUBLE","operator":"CONSTANT","value":"617.69"}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_lifetime"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_order_items_per_account_number_30day"},{"type":"INT","operator":"CONSTANT","value":"3"}]},{"operator":"IS_NULL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_order_items_per_account_number_30day"}]}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_1day"},{"type":"DOUBLE","operator":"CONSTANT","value":"627.51999"}]},{"operator":"IS_NULL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_1day"}]}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'DOUBLE',
#         'value': 'account_number.avg_order_total_per_account_number_1day'},
#        {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 617.69}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_lifetime'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'INT',
#           'value': 'account_number.num_order_items_per_account_number_30day'},
#          {'operator': 'CONSTANT', 'type': 'INT', 'value': 3}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'INT',
#           'value': 'account_number.num_order_items_per_account_number_30day'}]}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_1day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 627.51999}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_1day'}]}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:19.991-08:00',
#    'matches': 0,
#    'rid': 2015,
#    'score': -6,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T08:28:27.184-08:00',
#    'id': 2000,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T11:38:21.839-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'HighFraudTxnPerAccountNum',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.num_fraud_transactions_per_account_number_1day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_1day", "type": "integer"}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.num_fraud_transactions_per_account_number_1day","field":"account_number.num_fraud_transactions_per_account_number_1day","type":"integer","operator":"greater_or_equal","value":"value.1"}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'id': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_1day"},{"type":"INT","operator":"CONSTANT","value":"1"}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_1day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]}]},
#    'entitiesProcessed': 0,
#    'javaElExpression': '',
#    'lastDateRuleConditionChanged': '2021-01-25T11:38:21.842-08:00',
#    'matches': 0,
#    'query': '',
#    'rid': 2000,
#    'score': -100,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T07:35:10.279-08:00',
#    'id': 1999,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T11:39:00.037-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'JavaEL',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition":"AND","rules":[{"id":"java_el","field":"java_el","type":"string","input":"text","operator":"java_el","value":"${table_values.$billing_city.toLowerCase().matches(\\".*(133 tuckerman st ne|1118 e fairmount ave|1120 e belvedere ave|1130 genei ct e|114w w 183rd st|116 s 198th pl|11800 nw 101st rd|14520 village dr|16009 hayland st|17030 point pleasant ln|251 s main st|25883 n park ave|336 wayne st|4411 nw 74th ave|5015 silent lk|64 robin hood ln|703 8th st|7231 boulder ave|912 n van ness ave|23113 sw 113th ave|14050 cherry ave|1707 pleasanton rd|22 e mission ave|3353 sunglow dr|408 mohawk st sw|47705 state highway 11|4779 123rd trl n|4779 123rd trl n west palm bch|59 e mcmicken ave|590 n brown st|6696 e oakridge st|741 globe ave|801 mildred st|8601 nw 27th st|310n n dalton ave|3186 contra loma blvd|4089 windward dr|5522 paschall ave|6387 evesham dr|6786 ryan hwy|806 clover ln|8298 nw 68th st evc 816|18432 ne sandy blvd|7147 marysville pl|2405 hollowridge ln|131 hebert rd|7515 n leadbetter rd|oxford|french|in providence ri|manton in providence ri)\\\\\\\\b.*\\") }","data":{}}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"java_el","field":"java_el","type":"string","input":"text","operator":"java_el","value":"${table_values.$billing_city.toLowerCase().matches(\\".*(133 tuckerman st ne|1118 e fairmount ave|1120 e belvedere ave|1130 genei ct e|114w w 183rd st|116 s 198th pl|11800 nw 101st rd|14520 village dr|16009 hayland st|17030 point pleasant ln|251 s main st|25883 n park ave|336 wayne st|4411 nw 74th ave|5015 silent lk|64 robin hood ln|703 8th st|7231 boulder ave|912 n van ness ave|23113 sw 113th ave|14050 cherry ave|1707 pleasanton rd|22 e mission ave|3353 sunglow dr|408 mohawk st sw|47705 state highway 11|4779 123rd trl n|4779 123rd trl n west palm bch|59 e mcmicken ave|590 n brown st|6696 e oakridge st|741 globe ave|801 mildred st|8601 nw 27th st|310n n dalton ave|3186 contra loma blvd|4089 windward dr|5522 paschall ave|6387 evesham dr|6786 ryan hwy|806 clover ln|8298 nw 68th st evc 816|18432 ne sandy blvd|7147 marysville pl|2405 hollowridge ln|131 hebert rd|7515 n leadbetter rd|oxford|french|in providence ri|manton in providence ri)\\\\\\\\b.*\\") }","data":{}}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'data': [''],
#       'field': 'java_el',
#       'id': 'java_el',
#       'input': 'text',
#       'operator': 'java_el',
#       'type': 'string',
#       'value': '${table_values.$billing_city.toLowerCase().matches(".*(133 tuckerman st ne|1118 e fairmount ave|1120 e belvedere ave|1130 genei ct e|114w w 183rd st|116 s 198th pl|11800 nw 101st rd|14520 village dr|16009 hayland st|17030 point pleasant ln|251 s main st|25883 n park ave|336 wayne st|4411 nw 74th ave|5015 silent lk|64 robin hood ln|703 8th st|7231 boulder ave|912 n van ness ave|23113 sw 113th ave|14050 cherry ave|1707 pleasanton rd|22 e mission ave|3353 sunglow dr|408 mohawk st sw|47705 state highway 11|4779 123rd trl n|4779 123rd trl n west palm bch|59 e mcmicken ave|590 n brown st|6696 e oakridge st|741 globe ave|801 mildred st|8601 nw 27th st|310n n dalton ave|3186 contra loma blvd|4089 windward dr|5522 paschall ave|6387 evesham dr|6786 ryan hwy|806 clover ln|8298 nw 68th st evc 816|18432 ne sandy blvd|7147 marysville pl|2405 hollowridge ln|131 hebert rd|7515 n leadbetter rd|oxford|french|in providence ri|manton in providence ri)\\\\b.*") }'}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"type":"BOOLEAN","operator":"JAVA_EL","value":"${table_values.$billing_city.toLowerCase().matches(\\".*(133 tuckerman st ne|1118 e fairmount ave|1120 e belvedere ave|1130 genei ct e|114w w 183rd st|116 s 198th pl|11800 nw 101st rd|14520 village dr|16009 hayland st|17030 point pleasant ln|251 s main st|25883 n park ave|336 wayne st|4411 nw 74th ave|5015 silent lk|64 robin hood ln|703 8th st|7231 boulder ave|912 n van ness ave|23113 sw 113th ave|14050 cherry ave|1707 pleasanton rd|22 e mission ave|3353 sunglow dr|408 mohawk st sw|47705 state highway 11|4779 123rd trl n|4779 123rd trl n west palm bch|59 e mcmicken ave|590 n brown st|6696 e oakridge st|741 globe ave|801 mildred st|8601 nw 27th st|310n n dalton ave|3186 contra loma blvd|4089 windward dr|5522 paschall ave|6387 evesham dr|6786 ryan hwy|806 clover ln|8298 nw 68th st evc 816|18432 ne sandy blvd|7147 marysville pl|2405 hollowridge ln|131 hebert rd|7515 n leadbetter rd|oxford|french|in providence ri|manton in providence ri)\\\\\\\\b.*\\") }"}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'JAVA_EL',
#       'type': 'BOOLEAN',
#       'value': '${table_values.$billing_city.toLowerCase().matches(".*(133 tuckerman st ne|1118 e fairmount ave|1120 e belvedere ave|1130 genei ct e|114w w 183rd st|116 s 198th pl|11800 nw 101st rd|14520 village dr|16009 hayland st|17030 point pleasant ln|251 s main st|25883 n park ave|336 wayne st|4411 nw 74th ave|5015 silent lk|64 robin hood ln|703 8th st|7231 boulder ave|912 n van ness ave|23113 sw 113th ave|14050 cherry ave|1707 pleasanton rd|22 e mission ave|3353 sunglow dr|408 mohawk st sw|47705 state highway 11|4779 123rd trl n|4779 123rd trl n west palm bch|59 e mcmicken ave|590 n brown st|6696 e oakridge st|741 globe ave|801 mildred st|8601 nw 27th st|310n n dalton ave|3186 contra loma blvd|4089 windward dr|5522 paschall ave|6387 evesham dr|6786 ryan hwy|806 clover ln|8298 nw 68th st evc 816|18432 ne sandy blvd|7147 marysville pl|2405 hollowridge ln|131 hebert rd|7515 n leadbetter rd|oxford|french|in providence ri|manton in providence ri)\\\\b.*") }'}]},
#    'entitiesProcessed': 0,
#    'javaElExpression': '',
#    'lastDateRuleConditionChanged': '2021-01-25T11:26:40.962-08:00',
#    'matches': 0,
#    'query': '',
#    'rid': 1999,
#    'score': -14,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:04.218-08:00',
#    'id': 2002,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:04.218-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule256',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.num_fraud_transactions_per_account_number_1day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_1day", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_90day", "operator": "less_or_equal", "value": "value.950.89999", "id": "account_number.sum_order_total_per_account_number_90day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_90day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_90day", "type": "double"}]}, {"field": "is_billing_shipping_city_same", "operator": "equal", "value": "0", "id": "is_billing_shipping_city_same", "type": "boolean", "input": "radio"}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.num_fraud_transactions_per_account_number_1day","field":"account_number.num_fraud_transactions_per_account_number_1day","type":"integer","operator":"greater_or_equal","value":"value.1"},{"condition":"OR","rules":[{"id":"account_number.sum_order_total_per_account_number_90day","field":"account_number.sum_order_total_per_account_number_90day","type":"double","operator":"less_or_equal","value":"value.950.89999"},{"id":"account_number.sum_order_total_per_account_number_90day","field":"account_number.sum_order_total_per_account_number_90day","type":"double","operator":"is_null"}]},{"id":"is_billing_shipping_city_same","field":"is_billing_shipping_city_same","type":"boolean","input":"radio","operator":"equal","value":"0"}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'id': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.sum_order_total_per_account_number_90day',
#         'id': 'account_number.sum_order_total_per_account_number_90day',
#         'operator': 'less_or_equal',
#         'type': 'double',
#         'value': 'value.950.89999'},
#        {'field': 'account_number.sum_order_total_per_account_number_90day',
#         'id': 'account_number.sum_order_total_per_account_number_90day',
#         'operator': 'is_null',
#         'type': 'double'}]},
#      {'field': 'is_billing_shipping_city_same',
#       'id': 'is_billing_shipping_city_same',
#       'input': 'radio',
#       'operator': 'equal',
#       'type': 'boolean',
#       'value': 0}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_1day"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_90day"},{"type":"DOUBLE","operator":"CONSTANT","value":"950.89999"}]},{"operator":"IS_NULL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_90day"}]}]},{"operator":"EQUAL","rules":[{"type":"BOOLEAN","operator":"TABLE_VALUE","value":"is_billing_shipping_city_same"},{"type":"BOOLEAN","operator":"CONSTANT","value":"false"}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_1day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_90day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 950.89999}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_90day'}]}]},
#      {'operator': 'EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'BOOLEAN',
#         'value': 'is_billing_shipping_city_same'},
#        {'operator': 'CONSTANT', 'type': 'BOOLEAN', 'value': False}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:04.660-08:00',
#    'matches': 0,
#    'rid': 2002,
#    'score': -41,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:05.485-08:00',
#    'id': 2003,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:05.485-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule35',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.num_fraud_transactions_per_account_number_7day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_7day", "type": "integer"}, {"field": "account_number.num_fraud_transactions_per_account_number_lifetime", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_lifetime", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.num_order_items_per_account_number_lifetime", "operator": "less_or_equal", "value": "value.5", "id": "account_number.num_order_items_per_account_number_lifetime", "type": "integer"}, {"field": "account_number.num_order_items_per_account_number_lifetime", "operator": "is_null", "value": null, "id": "account_number.num_order_items_per_account_number_lifetime", "type": "integer"}]}, {"field": "is_existing_user", "operator": "equal", "value": "1", "id": "is_existing_user", "type": "boolean", "input": "radio"}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.num_fraud_transactions_per_account_number_7day","field":"account_number.num_fraud_transactions_per_account_number_7day","type":"integer","operator":"greater_or_equal","value":"value.1"},{"id":"account_number.num_fraud_transactions_per_account_number_lifetime","field":"account_number.num_fraud_transactions_per_account_number_lifetime","type":"integer","operator":"greater_or_equal","value":"value.1"},{"condition":"OR","rules":[{"id":"account_number.num_order_items_per_account_number_lifetime","field":"account_number.num_order_items_per_account_number_lifetime","type":"integer","operator":"less_or_equal","value":"value.5"},{"id":"account_number.num_order_items_per_account_number_lifetime","field":"account_number.num_order_items_per_account_number_lifetime","type":"integer","operator":"is_null"}]},{"id":"is_existing_user","field":"is_existing_user","type":"boolean","input":"radio","operator":"equal","value":"1"}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.num_fraud_transactions_per_account_number_7day',
#       'id': 'account_number.num_fraud_transactions_per_account_number_7day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'id': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.num_order_items_per_account_number_lifetime',
#         'id': 'account_number.num_order_items_per_account_number_lifetime',
#         'operator': 'less_or_equal',
#         'type': 'integer',
#         'value': 'value.5'},
#        {'field': 'account_number.num_order_items_per_account_number_lifetime',
#         'id': 'account_number.num_order_items_per_account_number_lifetime',
#         'operator': 'is_null',
#         'type': 'integer'}]},
#      {'field': 'is_existing_user',
#       'id': 'is_existing_user',
#       'input': 'radio',
#       'operator': 'equal',
#       'type': 'boolean',
#       'value': 1}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_7day"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_lifetime"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_order_items_per_account_number_lifetime"},{"type":"INT","operator":"CONSTANT","value":"5"}]},{"operator":"IS_NULL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_order_items_per_account_number_lifetime"}]}]},{"operator":"EQUAL","rules":[{"type":"BOOLEAN","operator":"TABLE_VALUE","value":"is_existing_user"},{"type":"BOOLEAN","operator":"CONSTANT","value":"true"}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_7day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_lifetime'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'INT',
#           'value': 'account_number.num_order_items_per_account_number_lifetime'},
#          {'operator': 'CONSTANT', 'type': 'INT', 'value': 5}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'INT',
#           'value': 'account_number.num_order_items_per_account_number_lifetime'}]}]},
#      {'operator': 'EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'BOOLEAN',
#         'value': 'is_existing_user'},
#        {'operator': 'CONSTANT', 'type': 'BOOLEAN', 'value': True}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:05.866-08:00',
#    'matches': 0,
#    'rid': 2003,
#    'score': -35,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:06.721-08:00',
#    'id': 2004,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:06.721-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule193',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.num_distinct_transaction_per_account_number_30day", "operator": "greater_or_equal", "value": "value.2", "id": "account_number.num_distinct_transaction_per_account_number_30day", "type": "integer"}, {"field": "account_number.num_fraud_transactions_per_account_number_lifetime", "operator": "greater_or_equal", "value": "value.2", "id": "account_number.num_fraud_transactions_per_account_number_lifetime", "type": "integer"}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.num_distinct_transaction_per_account_number_30day","field":"account_number.num_distinct_transaction_per_account_number_30day","type":"integer","operator":"greater_or_equal","value":"value.2"},{"id":"account_number.num_fraud_transactions_per_account_number_lifetime","field":"account_number.num_fraud_transactions_per_account_number_lifetime","type":"integer","operator":"greater_or_equal","value":"value.2"}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.num_distinct_transaction_per_account_number_30day',
#       'id': 'account_number.num_distinct_transaction_per_account_number_30day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.2'},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'id': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.2'}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_distinct_transaction_per_account_number_30day"},{"type":"INT","operator":"CONSTANT","value":"2"}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_lifetime"},{"type":"INT","operator":"CONSTANT","value":"2"}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_distinct_transaction_per_account_number_30day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 2}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_lifetime'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 2}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:07.086-08:00',
#    'matches': 0,
#    'rid': 2004,
#    'score': -34,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:07.745-08:00',
#    'id': 2005,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:07.745-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule241',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.avg_order_total_per_account_number_90day", "operator": "greater", "value": "value.153.949", "id": "account_number.avg_order_total_per_account_number_90day", "type": "double"}, {"field": "account_number.num_fraud_transactions_per_account_number_1day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_1day", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_1day", "operator": "less_or_equal", "value": "value.623.10999", "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_1day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}]}, {"field": "account_number.sum_order_total_per_account_number_30day", "operator": "greater", "value": "value.329.12", "id": "account_number.sum_order_total_per_account_number_30day", "type": "double"}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.avg_order_total_per_account_number_90day","field":"account_number.avg_order_total_per_account_number_90day","type":"double","operator":"greater","value":"value.153.949"},{"id":"account_number.num_fraud_transactions_per_account_number_1day","field":"account_number.num_fraud_transactions_per_account_number_1day","type":"integer","operator":"greater_or_equal","value":"value.1"},{"condition":"OR","rules":[{"id":"account_number.sum_order_total_per_account_number_1day","field":"account_number.sum_order_total_per_account_number_1day","type":"double","operator":"less_or_equal","value":"value.623.10999"},{"id":"account_number.sum_order_total_per_account_number_1day","field":"account_number.sum_order_total_per_account_number_1day","type":"double","operator":"is_null"}]},{"id":"account_number.sum_order_total_per_account_number_30day","field":"account_number.sum_order_total_per_account_number_30day","type":"double","operator":"greater","value":"value.329.12"}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.avg_order_total_per_account_number_90day',
#       'id': 'account_number.avg_order_total_per_account_number_90day',
#       'operator': 'greater',
#       'type': 'double',
#       'value': 'value.153.949'},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'id': 'account_number.num_fraud_transactions_per_account_number_1day',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.sum_order_total_per_account_number_1day',
#         'id': 'account_number.sum_order_total_per_account_number_1day',
#         'operator': 'less_or_equal',
#         'type': 'double',
#         'value': 'value.623.10999'},
#        {'field': 'account_number.sum_order_total_per_account_number_1day',
#         'id': 'account_number.sum_order_total_per_account_number_1day',
#         'operator': 'is_null',
#         'type': 'double'}]},
#      {'field': 'account_number.sum_order_total_per_account_number_30day',
#       'id': 'account_number.sum_order_total_per_account_number_30day',
#       'operator': 'greater',
#       'type': 'double',
#       'value': 'value.329.12'}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.avg_order_total_per_account_number_90day"},{"type":"DOUBLE","operator":"CONSTANT","value":"153.949"}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_1day"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_1day"},{"type":"DOUBLE","operator":"CONSTANT","value":"623.10999"}]},{"operator":"IS_NULL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_1day"}]}]},{"operator":"GREATER_THAN","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_30day"},{"type":"DOUBLE","operator":"CONSTANT","value":"329.12"}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'DOUBLE',
#         'value': 'account_number.avg_order_total_per_account_number_90day'},
#        {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 153.949}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_1day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_1day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 623.10999}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_1day'}]}]},
#      {'operator': 'GREATER_THAN',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'DOUBLE',
#         'value': 'account_number.sum_order_total_per_account_number_30day'},
#        {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 329.12}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:08.116-08:00',
#    'matches': 0,
#    'rid': 2005,
#    'score': -26,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:08.972-08:00',
#    'id': 2006,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:08.972-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule263',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.num_fraud_transactions_per_account_number_30day", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_30day", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_1day", "operator": "less_or_equal", "value": "value.950.89999", "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_1day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_1day", "type": "double"}]}, {"field": "account_number.sum_order_total_per_account_number_7day", "operator": "greater", "value": "value.623.10999", "id": "account_number.sum_order_total_per_account_number_7day", "type": "double"}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_90day", "operator": "less_or_equal", "value": "value.929.77499", "id": "account_number.sum_order_total_per_account_number_90day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_90day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_90day", "type": "double"}]}]}',
# ...
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.avg_order_total_per_account_number_90day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 5.5}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.avg_order_total_per_account_number_90day'}]}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_distinct_transaction_per_account_number_30day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 2}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_30day'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_lifetime'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 2}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:21.046-08:00',
#    'matches': 0,
#    'rid': 2016,
#    'score': -6,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-01-25T10:25:21.906-08:00',
#    'id': 2017,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-01-25T10:25:21.906-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'RGDT_Rule24',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition": "AND", "rules": [{"field": "account_number.avg_order_total_per_account_number_90day", "operator": "greater", "value": "value.482.39583", "id": "account_number.avg_order_total_per_account_number_90day", "type": "double"}, {"field": "account_number.num_fraud_transactions_per_account_number_lifetime", "operator": "greater_or_equal", "value": "value.1", "id": "account_number.num_fraud_transactions_per_account_number_lifetime", "type": "integer"}, {"condition": "OR", "rules": [{"field": "account_number.num_order_items_per_account_number_lifetime", "operator": "less_or_equal", "value": "value.2", "id": "account_number.num_order_items_per_account_number_lifetime", "type": "integer"}, {"field": "account_number.num_order_items_per_account_number_lifetime", "operator": "is_null", "value": null, "id": "account_number.num_order_items_per_account_number_lifetime", "type": "integer"}]}, {"condition": "OR", "rules": [{"field": "account_number.sum_order_total_per_account_number_7day", "operator": "less_or_equal", "value": "value.618.095", "id": "account_number.sum_order_total_per_account_number_7day", "type": "double"}, {"field": "account_number.sum_order_total_per_account_number_7day", "operator": "is_null", "value": null, "id": "account_number.sum_order_total_per_account_number_7day", "type": "double"}]}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"account_number.avg_order_total_per_account_number_90day","field":"account_number.avg_order_total_per_account_number_90day","type":"double","operator":"greater","value":"value.482.39583"},{"id":"account_number.num_fraud_transactions_per_account_number_lifetime","field":"account_number.num_fraud_transactions_per_account_number_lifetime","type":"integer","operator":"greater_or_equal","value":"value.1"},{"condition":"OR","rules":[{"id":"account_number.num_order_items_per_account_number_lifetime","field":"account_number.num_order_items_per_account_number_lifetime","type":"integer","operator":"less_or_equal","value":"value.2"},{"id":"account_number.num_order_items_per_account_number_lifetime","field":"account_number.num_order_items_per_account_number_lifetime","type":"integer","operator":"is_null"}]},{"condition":"OR","rules":[{"id":"account_number.sum_order_total_per_account_number_7day","field":"account_number.sum_order_total_per_account_number_7day","type":"double","operator":"less_or_equal","value":"value.618.095"},{"id":"account_number.sum_order_total_per_account_number_7day","field":"account_number.sum_order_total_per_account_number_7day","type":"double","operator":"is_null"}]}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'field': 'account_number.avg_order_total_per_account_number_90day',
#       'id': 'account_number.avg_order_total_per_account_number_90day',
#       'operator': 'greater',
#       'type': 'double',
#       'value': 'value.482.39583'},
#      {'field': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'id': 'account_number.num_fraud_transactions_per_account_number_lifetime',
#       'operator': 'greater_or_equal',
#       'type': 'integer',
#       'value': 'value.1'},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.num_order_items_per_account_number_lifetime',
#         'id': 'account_number.num_order_items_per_account_number_lifetime',
#         'operator': 'less_or_equal',
#         'type': 'integer',
#         'value': 'value.2'},
#        {'field': 'account_number.num_order_items_per_account_number_lifetime',
#         'id': 'account_number.num_order_items_per_account_number_lifetime',
#         'operator': 'is_null',
#         'type': 'integer'}]},
#      {'condition': 'OR',
#       'rules': [{'field': 'account_number.sum_order_total_per_account_number_7day',
#         'id': 'account_number.sum_order_total_per_account_number_7day',
#         'operator': 'less_or_equal',
#         'type': 'double',
#         'value': 'value.618.095'},
#        {'field': 'account_number.sum_order_total_per_account_number_7day',
#         'id': 'account_number.sum_order_total_per_account_number_7day',
#         'operator': 'is_null',
#         'type': 'double'}]}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.avg_order_total_per_account_number_90day"},{"type":"DOUBLE","operator":"CONSTANT","value":"482.39583"}]},{"operator":"GREATER_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_fraud_transactions_per_account_number_lifetime"},{"type":"INT","operator":"CONSTANT","value":"1"}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_order_items_per_account_number_lifetime"},{"type":"INT","operator":"CONSTANT","value":"2"}]},{"operator":"IS_NULL","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"account_number.num_order_items_per_account_number_lifetime"}]}]},{"operator":"OR","rules":[{"operator":"LESS_THAN_OR_EQUAL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_7day"},{"type":"DOUBLE","operator":"CONSTANT","value":"618.095"}]},{"operator":"IS_NULL","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"account_number.sum_order_total_per_account_number_7day"}]}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'DOUBLE',
#         'value': 'account_number.avg_order_total_per_account_number_90day'},
#        {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 482.39583}]},
#      {'operator': 'GREATER_THAN_OR_EQUAL',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'account_number.num_fraud_transactions_per_account_number_lifetime'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 1}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'INT',
#           'value': 'account_number.num_order_items_per_account_number_lifetime'},
#          {'operator': 'CONSTANT', 'type': 'INT', 'value': 2}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'INT',
#           'value': 'account_number.num_order_items_per_account_number_lifetime'}]}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'LESS_THAN_OR_EQUAL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_7day'},
#          {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 618.095}]},
#        {'operator': 'IS_NULL',
#         'rules': [{'operator': 'TABLE_VALUE',
#           'type': 'DOUBLE',
#           'value': 'account_number.sum_order_total_per_account_number_7day'}]}]}]},
#    'entitiesProcessed': 0,
#    'isAutoGenerated': True,
#    'lastDateRuleConditionChanged': '2021-01-25T10:25:22.236-08:00',
#    'matches': 0,
#    'rid': 2017,
#    'score': -6,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0},
#   {'createdBy': 'james@simility.com',
#    'createdOn': '2021-02-11T01:51:03.168-08:00',
#    'id': 2025,
#    'modifiedBy': 'james@simility.com',
#    'modifiedOn': '2021-02-11T05:40:10.666-08:00',
#    'appPrefix': 'james_testing',
#    'entityName': 'transaction',
#    'name': 'ComplicatedRule',
#    'casesCaughtByRule': 0,
#    'conditions': '{"condition":"AND","rules":[{"id":"num_order_items","field":"num_order_items","type":"integer","operator":"greater","value":"value.5","data":{}},{"condition":"OR","rules":[{"condition":"AND","rules":[{"id":"order_total","field":"order_total","type":"double","operator":"greater","value":"value.1000"},{"id":"is_existing_user","field":"is_existing_user","type":"boolean","input":"radio","operator":"equal","value":"1"}]},{"condition":"AND","rules":[{"id":"order_total","field":"order_total","type":"double","operator":"greater","value":"value.500"},{"id":"is_existing_user","field":"is_existing_user","type":"boolean","input":"radio","operator":"equal","value":"0"}]},{"condition":"OR","rules":[{"id":"billing_city","field":"billing_city","type":"string","operator":"begins_with","value":"value.B"}]}],"data":{}}]}',
#    'conditionsCleaned': '{"condition":"AND","rules":[{"id":"num_order_items","field":"num_order_items","type":"integer","operator":"greater","value":"value.5","data":{}},{"condition":"OR","rules":[{"condition":"AND","rules":[{"id":"order_total","field":"order_total","type":"double","operator":"greater","value":"value.1000"},{"id":"is_existing_user","field":"is_existing_user","type":"boolean","input":"radio","operator":"equal","value":"1"}]},{"condition":"AND","rules":[{"id":"order_total","field":"order_total","type":"double","operator":"greater","value":"value.500"},{"id":"is_existing_user","field":"is_existing_user","type":"boolean","input":"radio","operator":"equal","value":"0"}]},{"condition":"OR","rules":[{"id":"billing_city","field":"billing_city","type":"string","operator":"begins_with","value":"value.B"}]}],"data":{}}]}',
#    'conditionsJson': {'condition': 'AND',
#     'rules': [{'data': [''],
#       'field': 'num_order_items',
#       'id': 'num_order_items',
#       'operator': 'greater',
#       'type': 'integer',
#       'value': 'value.5'},
#      {'condition': 'OR',
#       'data': [''],
#       'rules': [{'condition': 'AND',
#         'rules': [{'field': 'order_total',
#           'id': 'order_total',
#           'operator': 'greater',
#           'type': 'double',
#           'value': 'value.1000'},
#          {'field': 'is_existing_user',
#           'id': 'is_existing_user',
#           'input': 'radio',
#           'operator': 'equal',
#           'type': 'boolean',
#           'value': 1}]},
#        {'condition': 'AND',
#         'rules': [{'field': 'order_total',
#           'id': 'order_total',
#           'operator': 'greater',
#           'type': 'double',
#           'value': 'value.500'},
#          {'field': 'is_existing_user',
#           'id': 'is_existing_user',
#           'input': 'radio',
#           'operator': 'equal',
#           'type': 'boolean',
#           'value': 0}]},
#        {'condition': 'OR',
#         'rules': [{'field': 'billing_city',
#           'id': 'billing_city',
#           'operator': 'begins_with',
#           'type': 'string',
#           'value': 'value.B'}]}]}]},
#    'conditionsV2': '{"operator":"AND","rules":[{"operator":"GREATER_THAN","rules":[{"type":"INT","operator":"TABLE_VALUE","value":"num_order_items"},{"type":"INT","operator":"CONSTANT","value":"5"}]},{"operator":"OR","rules":[{"operator":"AND","rules":[{"operator":"GREATER_THAN","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"order_total"},{"type":"DOUBLE","operator":"CONSTANT","value":"1000.0"}]},{"operator":"EQUAL","rules":[{"type":"BOOLEAN","operator":"TABLE_VALUE","value":"is_existing_user"},{"type":"BOOLEAN","operator":"CONSTANT","value":"true"}]}]},{"operator":"AND","rules":[{"operator":"GREATER_THAN","rules":[{"type":"DOUBLE","operator":"TABLE_VALUE","value":"order_total"},{"type":"DOUBLE","operator":"CONSTANT","value":"500.0"}]},{"operator":"EQUAL","rules":[{"type":"BOOLEAN","operator":"TABLE_VALUE","value":"is_existing_user"},{"type":"BOOLEAN","operator":"CONSTANT","value":"false"}]}]},{"operator":"OR","rules":[{"operator":"STARTS_WITH","rules":[{"type":"TEXT","operator":"TABLE_VALUE","value":"billing_city"},{"type":"TEXT","operator":"CONSTANT","value":"B"}]}]}]}]}',
#    'conditionsV2Json': {'operator': 'AND',
#     'rules': [{'operator': 'GREATER_THAN',
#       'rules': [{'operator': 'TABLE_VALUE',
#         'type': 'INT',
#         'value': 'num_order_items'},
#        {'operator': 'CONSTANT', 'type': 'INT', 'value': 5}]},
#      {'operator': 'OR',
#       'rules': [{'operator': 'AND',
#         'rules': [{'operator': 'GREATER_THAN',
#           'rules': [{'operator': 'TABLE_VALUE',
#             'type': 'DOUBLE',
#             'value': 'order_total'},
#            {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 1000}]},
#          {'operator': 'EQUAL',
#           'rules': [{'operator': 'TABLE_VALUE',
#             'type': 'BOOLEAN',
#             'value': 'is_existing_user'},
#            {'operator': 'CONSTANT', 'type': 'BOOLEAN', 'value': True}]}]},
#        {'operator': 'AND',
#         'rules': [{'operator': 'GREATER_THAN',
#           'rules': [{'operator': 'TABLE_VALUE',
#             'type': 'DOUBLE',
#             'value': 'order_total'},
#            {'operator': 'CONSTANT', 'type': 'DOUBLE', 'value': 500}]},
#          {'operator': 'EQUAL',
#           'rules': [{'operator': 'TABLE_VALUE',
#             'type': 'BOOLEAN',
#             'value': 'is_existing_user'},
#            {'operator': 'CONSTANT', 'type': 'BOOLEAN', 'value': False}]}]},
#        {'operator': 'OR',
#         'rules': [{'operator': 'STARTS_WITH',
#           'rules': [{'operator': 'TABLE_VALUE',
#             'type': 'TEXT',
#             'value': 'billing_city'},
#            {'operator': 'CONSTANT', 'type': 'TEXT', 'value': 'B'}]}]}]}]},
#    'entitiesProcessed': 0,
#    'javaElExpression': '',
#    'lastDateRuleConditionChanged': '2021-02-11T05:40:10.672-08:00',
#    'matches': 0,
#    'query': '',
#    'rid': 2025,
#    'score': 0,
#    'status': 'ACTIVE',
#    'totalCases': 0,
#    'totalEntities': 0}]}

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.request()* method returns the stringified JSON containing the rule configuration JSONs for each rule in a Simility environment. The first level of the JSON contains one key - *entries*. This is a list which contains the rule configuration JSON for each rule in the Simility environment.

# %% [markdown]
# ## ReturnCassandraEntityInfoAPI

# %% [markdown]
# This class returns the information related to all Cassandra entities within a keyspace in a given a Simility environment.

# %% [markdown]
# Firstly, we need to instantiate the ReturnCassandraEntityInfoAPI class. To do this, we need to provide the *url*, *app_prefix* and *user* for the environment we're interested in.

# %%
params = {
    "url": 'http://sim-ds.us-central1.gcp.dev.paypalinc.com',
    "app_prefix": 'james_testing',
    "user": 'james@simility.com'
}

# %%
r = ReturnCassandraEntityInfoAPI(**params)

# %% [markdown]
# ---

# %% [markdown]
# Then we can run the *.request()* method to return the information related to all Cassandra entities within a keyspace in a given a Simility environment. **Note that the response is a raw stringified JSON - we need to convert it to a dictionary before it can be used in Python.**

# %%
response = r.request()

# %%
response_dict = json.loads(response.text)

# %%
response_dict
# Out:
# {'appId': 31,
#  'entities': [{'entity': {'createdBy': 'james@simility.com',
#     'createdOn': '2020-02-20T12:13:53.839-08:00',
#     'id': 198,
#     'modifiedBy': 'james@simility.com',
#     'modifiedOn': '2020-02-20T12:13:53.839-08:00',
#     'appPrefix': 'james_testing',
#     'additionalFields': '',
#     'classifier': '',
#     'description': '',
#     'icon': 'DEFAULT',
#     'ingressTable': False,
#     'inlineMaxExecTime': 0,
#     'inlinePipeline': False,
#     'inlineWebhook': False,
#     'mainFields': '',
#     'mainViews': '',
#     'name': 'account_number',
#     'pipelineEntity': False,
#     'postDecisionPipeline': False,
#     'queueTakenMaxSize': 0,
#     'queueTakenTimeoutMins': 0,
#     'realtimeWebhook': False,
#     'requiredFieldsMap': '',
#     'rid': 198,
#     'streamingPipeline': False,
#     'tableName': 'account_number',
#     'visible': True,
#     'webHookQPS': 0,
#     'webhookOnClosed': False,
#     'webhookOnEscalated': False},
#    'entityId': 198,
#    'entityName': 'account_number',
#    'fields': [{'name': 'avg_order_total_per_account_number_1day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'avg_order_total_per_account_number_30day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'avg_order_total_per_account_number_7day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'avg_order_total_per_account_number_90day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'eid', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'num_distinct_transaction_per_account_number_1day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'INT'},
#     {'name': 'num_distinct_transaction_per_account_number_30day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'INT'},
#     {'name': 'num_distinct_transaction_per_account_number_7day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'INT'},
#     {'name': 'num_distinct_transaction_per_account_number_90day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'INT'},
#     {'name': 'num_fraud_transactions_per_account_number_1day',
#      'repeated': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'type': 'INT'},
#     {'name': 'num_fraud_transactions_per_account_number_30day',
#      'repeated': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'type': 'INT'},
#     {'name': 'num_fraud_transactions_per_account_number_7day',
#      'repeated': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'type': 'INT'},
#     {'name': 'num_fraud_transactions_per_account_number_90day',
#      'repeated': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'type': 'INT'},
#     {'name': 'num_fraud_transactions_per_account_number_lifetime',
#      'repeated': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'type': 'INT'},
#     {'name': 'num_order_items_per_account_number_1day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'type': 'INT'},
#     {'name': 'num_order_items_per_account_number_30day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'type': 'INT'},
#     {'name': 'num_order_items_per_account_number_7day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'type': 'INT'},
#     {'name': 'num_order_items_per_account_number_90day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'type': 'INT'},
#     {'name': 'num_order_items_per_account_number_lifetime',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'type': 'INT'},
#     {'name': 'sim_bl', 'repeated': False, 'type': 'BOOLEAN'},
#     {'name': 'sim_created_at', 'repeated': False, 'type': 'TIMESTAMP'},
#     {'name': 'sim_creation_date', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_dc', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_dc_reasons', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_frequently_used', 'repeated': False, 'type': 'BOOLEAN'},
#     {'name': 'sim_is_fraud', 'repeated': False, 'type': 'INT'},
#     {'name': 'sim_ladt', 'repeated': False, 'type': 'TIMESTAMP'},
#     {'name': 'sim_ll', 'repeated': False, 'type': 'MAP'},
#     {'name': 'sim_local_feedback_status', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_map_tombstones', 'repeated': False, 'type': 'MAP'},
#     {'name': 'sim_ps', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_ps1', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_ps2', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_ps_error', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_q', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_qadtr', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_qnote', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_queues', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_sc', 'repeated': False, 'type': 'FLOAT'},
#     {'name': 'sim_sc_ml', 'repeated': False, 'type': 'FLOAT'},
#     {'name': 'sim_updated_at', 'repeated': False, 'type': 'TIMESTAMP'},
#     {'name': 'sim_updated_customer', 'repeated': False, 'type': 'TIMESTAMP'},
#     {'name': 'sim_updated_internal', 'repeated': False, 'type': 'TIMESTAMP'},
#     {'name': 'sim_updated_user_email', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sim_wl', 'repeated': False, 'type': 'SET'},
#     {'name': 'sim_wl2', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'sum_order_total_per_account_number_1day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'sum_order_total_per_account_number_30day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'sum_order_total_per_account_number_7day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'sum_order_total_per_account_number_90day',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'DOUBLE'},
#     {'name': 'transaction_proto',
#      'repeated': False,
#      'sources': 'SIGNAL: pdf01_collect_transactions',
#      'type': 'BLOB'},
#     {'name': 'transaction_proto_aggregations',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'type': 'TEXT'},
#     {'name': 'transaction_proto_num_order_items_aggregations',
#      'repeated': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'type': 'TEXT'},
#     {'name': 'transaction_proto_sim_is_fraud_aggregations',
#      'repeated': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'type': 'TEXT'}],
#    'metas': [{'id': 25430,
#      'modifiedOn': '2020-02-20T12:13:55.533-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'eid',
#      'columnName': 'eid',
#      'displayName': 'eid',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25430,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25447,
#      'modifiedOn': '2020-02-20T12:14:00.266-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_qadtr',
#      'columnName': 'sim_qadtr',
#      'displayName': 'sim_qadtr',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25447,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25448,
#      'modifiedOn': '2020-02-20T12:14:00.540-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_qnote',
#      'columnName': 'sim_qnote',
#      'displayName': 'sim_qnote',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25448,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25449,
#      'modifiedOn': '2020-02-20T12:14:00.811-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_queues',
#      'columnName': 'sim_queues',
#      'displayName': 'sim_queues',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25449,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25450,
#      'modifiedOn': '2020-02-20T12:14:01.080-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_sc',
#      'columnName': 'sim_sc',
#      'displayName': 'sim_sc',
#      'fieldType': 'FLOAT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25450,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25451,
#      'modifiedOn': '2020-02-20T12:14:01.348-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_sc_ml',
#      'columnName': 'sim_sc_ml',
#      'displayName': 'sim_sc_ml',
#      'fieldType': 'FLOAT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25451,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25452,
#      'modifiedOn': '2020-02-20T12:14:01.620-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_updated_at',
#      'columnName': 'sim_updated_at',
#      'displayName': 'sim_updated_at',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25452,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25453,
#      'modifiedOn': '2020-02-20T12:14:01.888-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_updated_customer',
#      'columnName': 'sim_updated_customer',
#      'displayName': 'sim_updated_customer',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25453,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25454,
#      'modifiedOn': '2020-02-20T12:14:02.154-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_updated_internal',
#      'columnName': 'sim_updated_internal',
#      'displayName': 'sim_updated_internal',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25454,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25455,
#      'modifiedOn': '2020-02-20T12:14:02.423-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_updated_user_email',
#      'columnName': 'sim_updated_user_email',
#      'displayName': 'sim_updated_user_email',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25455,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25456,
#      'modifiedOn': '2020-02-20T12:14:02.735-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_wl',
#      'columnName': 'sim_wl',
#      'displayName': 'sim_wl',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25456,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25457,
#      'modifiedOn': '2020-02-20T12:14:03-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_wl2',
#      'columnName': 'sim_wl2',
#      'displayName': 'sim_wl2',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25457,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25519,
#      'modifiedOn': '2020-02-20T16:51:27.075-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'avg_order_total_per_account_number_30day',
#      'columnName': 'avg_order_total_per_account_number_30day',
#      'displayName': 'avg_order_total_per_account_number_30day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25519,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25520,
#      'modifiedOn': '2020-02-20T16:51:27.415-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sum_order_total_per_account_number_90day',
#      'columnName': 'sum_order_total_per_account_number_90day',
#      'displayName': 'sum_order_total_per_account_number_90day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25520,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25521,
#      'modifiedOn': '2020-02-20T16:51:27.731-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_distinct_transaction_per_account_number_90day',
#      'columnName': 'num_distinct_transaction_per_account_number_90day',
#      'displayName': 'num_distinct_transaction_per_account_number_90day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25521,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25522,
#      'modifiedOn': '2020-02-20T16:51:28.049-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'avg_order_total_per_account_number_90day',
#      'columnName': 'avg_order_total_per_account_number_90day',
#      'displayName': 'avg_order_total_per_account_number_90day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25522,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25532,
#      'modifiedOn': '2020-02-20T16:58:48.452-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_order_items_per_account_number_7day',
#      'columnName': 'num_order_items_per_account_number_7day',
#      'displayName': 'num_order_items_per_account_number_7day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25532,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25533,
#      'modifiedOn': '2020-02-20T16:58:48.788-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_order_items_per_account_number_30day',
#      'columnName': 'num_order_items_per_account_number_30day',
#      'displayName': 'num_order_items_per_account_number_30day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25533,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25534,
#      'modifiedOn': '2020-02-20T16:58:49.116-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_order_items_per_account_number_90day',
#      'columnName': 'num_order_items_per_account_number_90day',
#      'displayName': 'num_order_items_per_account_number_90day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25534,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25523,
#      'modifiedOn': '2020-02-20T16:55:14.883-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'transaction_proto_sim_is_fraud_aggregations',
#      'columnName': 'transaction_proto_sim_is_fraud_aggregations',
#      'displayName': 'transaction_proto_sim_is_fraud_aggregations',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25523,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25524,
#      'modifiedOn': '2020-02-20T16:55:15.206-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_fraud_transactions_per_account_number_lifetime',
#      'columnName': 'num_fraud_transactions_per_account_number_lifetime',
#      'displayName': 'num_fraud_transactions_per_account_number_lifetime',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25524,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25525,
#      'modifiedOn': '2020-02-20T16:55:15.508-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_fraud_transactions_per_account_number_1day',
#      'columnName': 'num_fraud_transactions_per_account_number_1day',
#      'displayName': 'num_fraud_transactions_per_account_number_1day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25525,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25526,
#      'modifiedOn': '2020-02-20T16:55:15.815-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_fraud_transactions_per_account_number_7day',
#      'columnName': 'num_fraud_transactions_per_account_number_7day',
#      'displayName': 'num_fraud_transactions_per_account_number_7day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25526,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25527,
#      'modifiedOn': '2020-02-20T16:55:16.116-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_fraud_transactions_per_account_number_30day',
#      'columnName': 'num_fraud_transactions_per_account_number_30day',
#      'displayName': 'num_fraud_transactions_per_account_number_30day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25527,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25528,
#      'modifiedOn': '2020-02-20T16:55:16.417-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_fraud_transactions_per_account_number_90day',
#      'columnName': 'num_fraud_transactions_per_account_number_90day',
#      'displayName': 'num_fraud_transactions_per_account_number_90day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25528,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': ['SIGNAL: postrel02_account_number_proto_agg-copy',
#       'SIGNAL: postrel02_account_number_proto_sim_is_fraud_sums'],
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25529,
#      'modifiedOn': '2020-02-20T16:58:47.461-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'transaction_proto_num_order_items_aggregations',
#      'columnName': 'transaction_proto_num_order_items_aggregations',
#      'displayName': 'transaction_proto_num_order_items_aggregations',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25529,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25530,
#      'modifiedOn': '2020-02-20T16:58:47.799-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_order_items_per_account_number_lifetime',
#      'columnName': 'num_order_items_per_account_number_lifetime',
#      'displayName': 'num_order_items_per_account_number_lifetime',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25530,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25531,
#      'modifiedOn': '2020-02-20T16:58:48.131-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_order_items_per_account_number_1day',
#      'columnName': 'num_order_items_per_account_number_1day',
#      'displayName': 'num_order_items_per_account_number_1day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25531,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_num_items_sum',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25511,
#      'modifiedOn': '2020-02-20T16:51:24.290-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sum_order_total_per_account_number_1day',
#      'columnName': 'sum_order_total_per_account_number_1day',
#      'displayName': 'sum_order_total_per_account_number_1day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25511,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25512,
#      'modifiedOn': '2020-02-20T16:51:24.626-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_distinct_transaction_per_account_number_1day',
#      'columnName': 'num_distinct_transaction_per_account_number_1day',
#      'displayName': 'num_distinct_transaction_per_account_number_1day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25512,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'createdBy': 'james@simility.com',
#      'createdOn': '2020-02-20T16:39:03.567-08:00',
#      'id': 25508,
#      'modifiedBy': 'james@simility.com',
#      'modifiedOn': '2020-02-20T16:39:03.567-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'transaction_proto',
#      'columnName': 'transaction_proto',
#      'displayName': 'transaction_proto',
#      'fieldType': 'BLOB',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25508,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: pdf01_collect_transactions',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25510,
#      'modifiedOn': '2020-02-20T16:51:23.962-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'transaction_proto_aggregations',
#      'columnName': 'transaction_proto_aggregations',
#      'displayName': 'transaction_proto_aggregations',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25510,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25513,
#      'modifiedOn': '2020-02-20T16:51:25.010-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'avg_order_total_per_account_number_1day',
#      'columnName': 'avg_order_total_per_account_number_1day',
#      'displayName': 'avg_order_total_per_account_number_1day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25513,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25514,
#      'modifiedOn': '2020-02-20T16:51:25.356-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sum_order_total_per_account_number_7day',
#      'columnName': 'sum_order_total_per_account_number_7day',
#      'displayName': 'sum_order_total_per_account_number_7day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25514,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25515,
#      'modifiedOn': '2020-02-20T16:51:25.670-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_distinct_transaction_per_account_number_7day',
#      'columnName': 'num_distinct_transaction_per_account_number_7day',
#      'displayName': 'num_distinct_transaction_per_account_number_7day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25515,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25516,
#      'modifiedOn': '2020-02-20T16:51:25.984-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'avg_order_total_per_account_number_7day',
#      'columnName': 'avg_order_total_per_account_number_7day',
#      'displayName': 'avg_order_total_per_account_number_7day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25516,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25517,
#      'modifiedOn': '2020-02-20T16:51:26.392-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sum_order_total_per_account_number_30day',
#      'columnName': 'sum_order_total_per_account_number_30day',
#      'displayName': 'sum_order_total_per_account_number_30day',
#      'fieldType': 'DOUBLE',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25517,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25518,
#      'modifiedOn': '2020-02-20T16:51:26.705-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'num_distinct_transaction_per_account_number_30day',
#      'columnName': 'num_distinct_transaction_per_account_number_30day',
#      'displayName': 'num_distinct_transaction_per_account_number_30day',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25518,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'sources': 'SIGNAL: postrel02_account_number_proto_agg',
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25431,
#      'modifiedOn': '2020-02-20T12:13:55.848-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_bl',
#      'columnName': 'sim_bl',
#      'displayName': 'sim_bl',
#      'fieldType': 'BOOLEAN',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25431,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25432,
#      'modifiedOn': '2020-02-20T12:13:56.120-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_created_at',
#      'columnName': 'sim_created_at',
#      'displayName': 'sim_created_at',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25432,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25433,
#      'modifiedOn': '2020-02-20T12:13:56.405-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_creation_date',
#      'columnName': 'sim_creation_date',
#      'displayName': 'sim_creation_date',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25433,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25434,
#      'modifiedOn': '2020-02-20T12:13:56.690-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_dc',
#      'columnName': 'sim_dc',
#      'displayName': 'sim_dc',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25434,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25435,
#      'modifiedOn': '2020-02-20T12:13:56.994-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_dc_reasons',
#      'columnName': 'sim_dc_reasons',
#      'displayName': 'sim_dc_reasons',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25435,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25436,
#      'modifiedOn': '2020-02-20T12:13:57.266-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_frequently_used',
#      'columnName': 'sim_frequently_used',
#      'displayName': 'sim_frequently_used',
#      'fieldType': 'BOOLEAN',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25436,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25437,
#      'modifiedOn': '2020-02-20T12:13:57.562-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_is_fraud',
#      'columnName': 'sim_is_fraud',
#      'displayName': 'sim_is_fraud',
#      'fieldType': 'INT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25437,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25438,
#      'modifiedOn': '2020-02-20T12:13:57.827-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_ladt',
#      'columnName': 'sim_ladt',
#      'displayName': 'sim_ladt',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25438,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25439,
#      'modifiedOn': '2020-02-20T12:13:58.097-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_ll',
#      'columnName': 'sim_ll',
#      'displayName': 'sim_ll',
#      'fieldArgumentsType': ['TEXT', 'FLOAT'],
#      'fieldType': 'MAP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25439,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25440,
#      'modifiedOn': '2020-02-20T12:13:58.363-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_local_feedback_status',
#      'columnName': 'sim_local_feedback_status',
#      'displayName': 'sim_local_feedback_status',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25440,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25441,
#      'modifiedOn': '2020-02-20T12:13:58.633-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_map_tombstones',
#      'columnName': 'sim_map_tombstones',
#      'displayName': 'sim_map_tombstones',
#      'fieldArgumentsType': ['TEXT', 'BIGINT'],
#      'fieldType': 'MAP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25441,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25442,
#      'modifiedOn': '2020-02-20T12:13:58.902-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_ps',
#      'columnName': 'sim_ps',
#      'displayName': 'sim_ps',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25442,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25443,
#      'modifiedOn': '2020-02-20T12:13:59.179-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_ps1',
#      'columnName': 'sim_ps1',
#      'displayName': 'sim_ps1',
#      'fieldArgumentsType': 'UUID',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25443,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25444,
#      'modifiedOn': '2020-02-20T12:13:59.448-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_ps2',
#      'columnName': 'sim_ps2',
#      'displayName': 'sim_ps2',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25444,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25445,
#      'modifiedOn': '2020-02-20T12:13:59.719-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_ps_error',
#      'columnName': 'sim_ps_error',
#      'displayName': 'sim_ps_error',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25445,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25446,
#      'modifiedOn': '2020-02-20T12:13:59.989-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'account_number',
#      'name': 'sim_q',
#      'columnName': 'sim_q',
#      'displayName': 'sim_q',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25446,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'account_number',
#      'visible': True,
#      'whiteListed': False}]},
#   {'entity': {'id': 174,
#     'appPrefix': 'james_testing',
#     'ingressTable': False,
#     'inlineMaxExecTime': 0,
#     'inlinePipeline': False,
#     'inlineWebhook': False,
#     'name': 'device_signals_all',
#     'pipelineEntity': False,
#     'postDecisionPipeline': False,
#     'queueTakenMaxSize': 0,
#     'queueTakenTimeoutMins': 0,
#     'realtimeWebhook': False,
#     'requiredFieldsMap': '',
#     'rid': 174,
#     'sources': 'ONBOARDING',
#     'streamingPipeline': False,
#     'tableName': 'device_signals_all',
#     'visible': True,
#     'webHookQPS': 0,
#     'webhookOnClosed': False,
#     'webhookOnEscalated': False},
#    'entityId': 174,
#    'entityName': 'device_signals_all',
#    'fields': [{'name': 'android_accelerometer_data',
#      'repeated': False,
#      'type': 'LIST'},
#     {'name': 'android_accelerometer_name', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'android_accelerometer_power',
#      'repeated': False,
#      'type': 'DOUBLE'},
#     {'name': 'android_accelerometer_vendor',
#      'repeated': False,
#      'type': 'TEXT'},
#     {'name': 'android_accelerometer_version',
#      'repeated': False,
#      'type': 'INT'},
#     {'name': 'android_application_signature_set',
#      'repeated': False,
#      'type': 'SET'},
#     {'name': 'android_available_browser_packages',
#      'repeated': False,
#      'type': 'LIST'},
#     {'name': 'android_available_call_packages',
#      'repeated': False,
#      'type': 'LIST'},
#     {'name': 'android_available_external_storage',
#      'repeated': False,
#      'type': 'BIGINT'},
#     {'name': 'android_available_input_method_packages',
#      'repeated': False,
#      'type': 'LIST'},
#     {'name': 'android_available_internal_storage',
#      'repeated': False,
#      'type': 'BIGINT'},
#     {'name': 'android_available_launcher_packages',
#      'repeated': False,
#      'type': 'LIST'},
#     {'name': 'android_available_ram', 'repeated': False, 'type': 'BIGINT'},
#     {'name': 'android_available_sms_packages',
#      'repeated': False,
#      'type': 'LIST'},
#     {'name': 'android_battery_charging_type',
#      'repeated': False,
#      'type': 'TEXT'},
#     {'name': 'android_battery_percentage', 'repeated': False, 'type': 'INT'},
#     {'name': 'android_battery_technology', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'android_battery_temperature', 'repeated': False, 'type': 'INT'},
#     {'name': 'android_battery_voltage', 'repeated': False, 'type': 'INT'},
#     {'name': 'android_bluetooth_adapter_hardware_address',
#      'repeated': False,
#      'type': 'TEXT'},
#     {'name': 'android_bluetooth_adapter_name',
#      'repeated': False,
#      'type': 'TEXT'},
#     {'name': 'android_bluetooth_adapter_state',
#      'repeated': False,
#      'type': 'TEXT'},
#     {'name': 'android_build_board', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'android_build_bootloader', 'repeated': False, 'type': 'TEXT'},
#     {'name': 'android_build_brand', 'repeated': False, 'type': 'TEXT'},
# ...
#      'modifiedOn': '2020-02-20T12:13:28.610-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_q',
#      'columnName': 'sim_q',
#      'displayName': 'sim_q',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25418,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25419,
#      'modifiedOn': '2020-02-20T12:13:28.854-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_qadtr',
#      'columnName': 'sim_qadtr',
#      'displayName': 'sim_qadtr',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25419,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25420,
#      'modifiedOn': '2020-02-20T12:13:29.097-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_qnote',
#      'columnName': 'sim_qnote',
#      'displayName': 'sim_qnote',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25420,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25421,
#      'modifiedOn': '2020-02-20T12:13:29.342-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_queues',
#      'columnName': 'sim_queues',
#      'displayName': 'sim_queues',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25421,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25422,
#      'modifiedOn': '2020-02-20T12:13:29.586-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_sc',
#      'columnName': 'sim_sc',
#      'displayName': 'sim_sc',
#      'fieldType': 'FLOAT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25422,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25423,
#      'modifiedOn': '2020-02-20T12:13:29.832-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_sc_ml',
#      'columnName': 'sim_sc_ml',
#      'displayName': 'sim_sc_ml',
#      'fieldType': 'FLOAT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25423,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25424,
#      'modifiedOn': '2020-02-20T12:13:30.097-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_updated_at',
#      'columnName': 'sim_updated_at',
#      'displayName': 'sim_updated_at',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25424,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25425,
#      'modifiedOn': '2020-02-20T12:13:30.340-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_updated_customer',
#      'columnName': 'sim_updated_customer',
#      'displayName': 'sim_updated_customer',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25425,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25426,
#      'modifiedOn': '2020-02-20T12:13:30.583-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_updated_internal',
#      'columnName': 'sim_updated_internal',
#      'displayName': 'sim_updated_internal',
#      'fieldType': 'TIMESTAMP',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25426,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25427,
#      'modifiedOn': '2020-02-20T12:13:30.830-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_updated_user_email',
#      'columnName': 'sim_updated_user_email',
#      'displayName': 'sim_updated_user_email',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25427,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25428,
#      'modifiedOn': '2020-02-20T12:13:31.095-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_wl',
#      'columnName': 'sim_wl',
#      'displayName': 'sim_wl',
#      'fieldArgumentsType': 'TEXT',
#      'fieldType': 'SET',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25428,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False},
#     {'id': 25429,
#      'modifiedOn': '2020-02-20T12:13:31.352-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'name': 'sim_wl2',
#      'columnName': 'sim_wl2',
#      'displayName': 'sim_wl2',
#      'fieldType': 'TEXT',
#      'graphLinkVisible': True,
#      'ingressField': False,
#      'isSolrIndexed': False,
#      'isWhiteListed': False,
#      'loadReferences': True,
#      'propagatePipeline': False,
#      'rid': 25429,
#      'scope': 'ENTITY',
#      'solrIndexed': False,
#      'tableName': 'transaction',
#      'visible': True,
#      'whiteListed': False}],
#    'signals': [{'createdBy': 'james@simility.com',
#      'createdOn': '2020-02-20T16:39:24.514-08:00',
#      'id': 417,
#      'modifiedBy': 'james@simility.com',
#      'modifiedOn': '2020-02-20T16:39:24.514-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'executionType': 'Other',
#      'fields': ['eid'],
#      'fieldsSynced': True,
#      'inputParametersMap': {'entry': [{'key': 'account_number', 'value': ''},
#        {'key': 'transaction', 'value': ''}]},
#      'lastJobId': 0,
#      'matches': 0,
#      'outputParametersMap': {'entry': [{'key': 'account_number',
#         'value': ''}]},
#      'params': '[{"value5":null,"value4":null,"value3":"","value2":"","label":"EventName","value":"transaction"},{"value5":null,"value4":null,"value3":"","value2":"","label":"EIDFieldName","value":"@eid"},{"value5":null,"value4":null,"value3":"","value2":"","label":"TimestampColumn","value":"@sim_created_at"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OptionalFields","value":"@order_total, @sim_is_fraud, @num_order_items"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParam","value":"account_number.transaction_proto"},{"value5":null,"value4":null,"value3":"","value2":"","label":"MaxDays","value":""},{"value5":null,"value4":null,"value3":"","value2":"","label":"MaxElementNumber","value":""},{"value5":null,"value4":null,"value3":"","value2":"","label":"ExecutionType","value":""}]',
#      'rid': 417,
#      'signalState': 'ACTIVE',
#      'signalsProcessed': 0,
#      'template': 'Proto Buffer Event Collector',
#      'templateName': 'pdf01_collect_transactions',
#      'totalSignals': 0},
#     {'createdBy': 'james@simility.com',
#      'createdOn': '2020-02-20T16:51:04.113-08:00',
#      'id': 419,
#      'modifiedBy': 'james@simility.com',
#      'modifiedOn': '2020-02-20T16:51:04.113-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'executionType': 'Other',
#      'fields': ['order_total'],
#      'fieldsSynced': True,
#      'inputParametersMap': {'entry': [{'key': 'account_number', 'value': ''},
#        {'key': 'transaction', 'value': ''}]},
#      'lastJobId': 0,
#      'matches': 0,
#      'outputParametersMap': {'entry': [{'key': 'account_number',
#         'value': ''}]},
#      'params': '[{"value5":null,"value4":null,"value3":"","value2":"","label":"JSFunction","value":"CountSumAvgProto"},{"value5":null,"value4":null,"value3":"","value2":"","label":"InputParam","value":"@account_number.transaction_proto,@eid,order_total,day,1,7,30,90"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParam","value":"account_number.transaction_proto_aggregations, account_number.sum_order_total_per_account_number_1day, account_number.num_distinct_transaction_per_account_number_1day, account_number.avg_order_total_per_account_number_1day, account_number.sum_order_total_per_account_number_7day, account_number.num_distinct_transaction_per_account_number_7day, account_number.avg_order_total_per_account_number_7day, account_number.sum_order_total_per_account_number_30day, account_number.num_distinct_transaction_per_account_number_30day, account_number.avg_order_total_per_account_number_30day, account_number.sum_order_total_per_account_number_90day, account_number.num_distinct_transaction_per_account_number_90day, account_number.avg_order_total_per_account_number_90day"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParamDataType","value":"TEXT,DOUBLE,INT,DOUBLE,DOUBLE,INT,DOUBLE,DOUBLE,INT,DOUBLE,DOUBLE,INT,DOUBLE"},{"value5":null,"value4":null,"value3":"","value2":"","label":"ExecutionType","value":""}]',
#      'rid': 419,
#      'signalState': 'ACTIVE',
#      'signalsProcessed': 0,
#      'template': 'JavaScript Signal',
#      'templateName': 'postrel02_account_number_proto_agg',
#      'totalSignals': 0},
#     {'createdBy': 'james@simility.com',
#      'createdOn': '2020-02-20T16:58:38.753-08:00',
#      'id': 421,
#      'modifiedBy': 'james@simility.com',
#      'modifiedOn': '2020-02-20T16:58:38.753-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'executionType': 'Other',
#      'fields': ['order_total'],
#      'fieldsSynced': True,
#      'inputParametersMap': {'entry': [{'key': 'account_number', 'value': ''},
#        {'key': 'transaction', 'value': ''}]},
#      'lastJobId': 0,
#      'matches': 0,
#      'outputParametersMap': {'entry': [{'key': 'account_number',
#         'value': ''}]},
#      'params': '[{"value5":null,"value4":null,"value3":"","value2":"","label":"JSFunction","value":"ProtoSum_only_INT"},{"value5":null,"value4":null,"value3":"","value2":"","label":"InputParam","value":"@account_number.transaction_proto,@eid,num_order_items"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParam","value":"account_number.transaction_proto_num_order_items_aggregations, account_number.num_order_items_per_account_number_lifetime, account_number.num_order_items_per_account_number_1day, account_number.num_order_items_per_account_number_7day, account_number.num_order_items_per_account_number_30day, account_number.num_order_items_per_account_number_90day"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParamDataType","value":"TEXT,INT,INT,INT,INT,INT"},{"value5":null,"value4":null,"value3":"","value2":"","label":"ExecutionType","value":""}]',
#      'rid': 421,
#      'signalState': 'ACTIVE',
#      'signalsProcessed': 0,
#      'template': 'JavaScript Signal',
#      'templateName': 'postrel02_account_number_proto_num_items_sum',
#      'totalSignals': 0},
#     {'createdBy': 'james@simility.com',
#      'createdOn': '2020-02-20T16:57:13.083-08:00',
#      'id': 420,
#      'modifiedBy': 'james@simility.com',
#      'modifiedOn': '2020-02-20T16:57:13.083-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'executionType': 'Other',
#      'fields': ['order_total'],
#      'fieldsSynced': True,
#      'inputParametersMap': {'entry': [{'key': 'account_number', 'value': ''},
#        {'key': 'transaction', 'value': ''}]},
#      'lastJobId': 0,
#      'matches': 0,
#      'outputParametersMap': {'entry': [{'key': 'account_number',
#         'value': ''}]},
#      'params': '[{"value5":null,"value4":null,"value3":"","value2":"","label":"JSFunction","value":"ProtoSum_only_INT"},{"value5":null,"value4":null,"value3":"","value2":"","label":"InputParam","value":"@account_number.transaction_proto,@eid,sim_is_fraud"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParam","value":"account_number.transaction_proto_sim_is_fraud_aggregations, account_number.num_fraud_transactions_per_account_number_lifetime, account_number.num_fraud_transactions_per_account_number_1day, account_number.num_fraud_transactions_per_account_number_7day, account_number.num_fraud_transactions_per_account_number_30day, account_number.num_fraud_transactions_per_account_number_90day"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParamDataType","value":"TEXT,INT,INT,INT,INT,INT"},{"value5":null,"value4":null,"value3":"","value2":"","label":"ExecutionType","value":""}]',
#      'rid': 420,
#      'signalState': 'ACTIVE',
#      'signalsProcessed': 0,
#      'template': 'JavaScript Signal',
#      'templateName': 'postrel02_account_number_proto_sim_is_fraud_sums',
#      'totalSignals': 0},
#     {'createdBy': 'james@simility.com',
#      'createdOn': '2020-02-20T16:45:29.056-08:00',
#      'id': 418,
#      'modifiedBy': 'james@simility.com',
#      'modifiedOn': '2020-02-20T16:45:29.056-08:00',
#      'appPrefix': 'james_testing',
#      'entityName': 'transaction',
#      'executionType': 'Other',
#      'fields': ['eid'],
#      'fieldsSynced': True,
#      'inputParametersMap': {'entry': [{'key': 'transaction', 'value': ''}]},
#      'lastJobId': 0,
#      'matches': 0,
#      'outputParametersMap': {'entry': [{'key': 'transaction', 'value': ''}]},
#      'params': '[{"value5":null,"value4":null,"value3":"","value2":"","label":"JSFunction","value":"IfAEqualsBThenTrueElseFalseLowercase"},{"value5":null,"value4":null,"value3":"","value2":"","label":"InputParam","value":"@billing_city,@shipping_city"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParam","value":"is_billing_shipping_city_same"},{"value5":null,"value4":null,"value3":"","value2":"","label":"OutParamDataType","value":"BOOLEAN"},{"value5":null,"value4":null,"value3":"","value2":"","label":"ExecutionType","value":""}]',
#      'rid': 418,
#      'signalState': 'ACTIVE',
#      'signalsProcessed': 0,
#      'template': 'JavaScript Signal',
#      'templateName': 'prerel01_is_billing_shipping_same',
#      'totalSignals': 0}]}],
#  'fieldTypes': ['BOOLEAN',
#   'FLOAT',
#   'DOUBLE',
#   'BIGINT',
#   'INT',
#   'TEXT',
#   'TIMESTAMP',
#   'VARCHAR',
#   'LIST',
#   'SET',
#   'MAP',
#   'MAPTEXTFLOAT',
#   'BLOB',
#   'MAPTEXTBLOB',
#   'UUID']}

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.request()* method returns the stringified JSON containing the information related to each entity in a Simility environment. The first level of the JSON contains three keys - *appId*, *entities* and *fieldTypes*. *entities* is a list which contains  the information related to each entity in a Simility environment

# %% [markdown]
# ----

# %% [markdown]
# ## The End

# %% [markdown]
# That's it folks - if you have any queries or suggestions please put them in the *#sim-datatools-help* Slack channel or email James directly.
